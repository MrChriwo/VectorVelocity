# %% [markdown]
# # PPO Baseline Training Notebook
#
# This Notebook contains the baseline model training for an PPO agent using stable_baselines3

# %% [markdown]
# ## Imports

# %%
from gym_vectorvelocity import VectorVelocityEnv
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from gymnasium import make 
from stable_baselines3 import PPO
import pandas as pd 

import tensorboardX
# Out:
# pygame-ce 2.4.1 (SDL 2.28.5, Python 3.11.5)

# %% [markdown]
# ## Settings

# %%
# general parameters, change as needed for your experiments

MODEL_NAME = "baseline_ppo" # name of the log folder and the model zip file
USE_MULTIPROCESSING = True # use multiprocessing via vec env or a single gym environment
USE_VERBOSE = True

# environment parameters
NUMBER_OF_STEPS = 2048
NUMBER_OF_ENVS = 10 # only if USE_MULTIPROCESSING is True
TOTAL_TIMESTEPS = 1e+5 # total timesteps for training

NUMBER_OF_EPOCHS = 10 
BATCH_SIZE = 64
LEARNING_RATE = 0.0001

LOG_DIR = "logs" # name of the folder where the logs will be stored

# env modifications if needed
GAMEOVER_PENALTY = 75
MISSED_COIN_PENALTY = 10

DODGED_OBSTACLE_REWARD = 1
COLLECTED_COIN_REWARD = 15


## the total time steps will be NUMBER_OF_ENVS * NUMBER_OF_TOTAL_STEPS, 
## comment out if you wont use this set up. it will then take the default value u have set :) 

if USE_MULTIPROCESSING:
    TOTAL_TIMESTEPS = NUMBER_OF_ENVS * TOTAL_TIMESTEPS

# %% [markdown]
# ## Setting up the Enviornment

# %% [markdown]
# ### Initilize and check

# %%
def create_env():
    env = VectorVelocityEnv()
    env.coin_missed_penalty = MISSED_COIN_PENALTY
    env.game_over_penalty = GAMEOVER_PENALTY
    env.dodged_obstacle_reward = DODGED_OBSTACLE_REWARD
    env.coin_reward = COLLECTED_COIN_REWARD
    return env

env = create_env()
check_env(env)

# %%
env.observation_space
# Out:
# Dict('coin_dists': Box(-1.0, 1.0, (40,), float32), 'coins': Box(-1.0, 1.0, (40,), float32), 'collected_coins': Discrete(20001), 'lane_coins': MultiDiscrete([4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4 4]), 'lane_obstacles': MultiDiscrete([4 4 4 4 4 4 4 4 4]), 'obstacle_dists': Box(-1.0, 1.0, (18,), float32), 'obstacles': Box(-1.0, 1.0, (18,), float32), 'player_pos': Box(0.0, 1.0, (1,), float32), 'score': Discrete(120001), 'speed': Discrete(20))

# %% [markdown]
# ### Env Setup

# %%
if USE_MULTIPROCESSING:
    env = make_vec_env(create_env, n_envs=NUMBER_OF_ENVS)
else:
    env = make(create_env)

# %% [markdown]
# ## Model & Training

# %% [markdown]
# ### Model Setup

# %%
model = PPO("MultiInputPolicy", 
            env, 
            verbose=USE_VERBOSE, 
            seed=42, 
            learning_rate=LEARNING_RATE,
            n_epochs=NUMBER_OF_EPOCHS,
            batch_size=BATCH_SIZE,
            tensorboard_log=LOG_DIR)
# Out:
# Using cuda device

# %%
model.policy
# Out:
# MultiInputActorCriticPolicy(
#   (features_extractor): CombinedExtractor(
#     (extractors): ModuleDict(
#       (coin_dists): Flatten(start_dim=1, end_dim=-1)
#       (coins): Flatten(start_dim=1, end_dim=-1)
#       (collected_coins): Flatten(start_dim=1, end_dim=-1)
#       (lane_coins): Flatten(start_dim=1, end_dim=-1)
#       (lane_obstacles): Flatten(start_dim=1, end_dim=-1)
#       (obstacle_dists): Flatten(start_dim=1, end_dim=-1)
#       (obstacles): Flatten(start_dim=1, end_dim=-1)
#       (player_pos): Flatten(start_dim=1, end_dim=-1)
#       (score): Flatten(start_dim=1, end_dim=-1)
#       (speed): Flatten(start_dim=1, end_dim=-1)
#     )
#   )
#   (pi_features_extractor): CombinedExtractor(
#     (extractors): ModuleDict(
#       (coin_dists): Flatten(start_dim=1, end_dim=-1)
#       (coins): Flatten(start_dim=1, end_dim=-1)
#       (collected_coins): Flatten(start_dim=1, end_dim=-1)
#       (lane_coins): Flatten(start_dim=1, end_dim=-1)
#       (lane_obstacles): Flatten(start_dim=1, end_dim=-1)
#       (obstacle_dists): Flatten(start_dim=1, end_dim=-1)
#       (obstacles): Flatten(start_dim=1, end_dim=-1)
#       (player_pos): Flatten(start_dim=1, end_dim=-1)
#       (score): Flatten(start_dim=1, end_dim=-1)
#       (speed): Flatten(start_dim=1, end_dim=-1)
#     )
#   )
#   (vf_features_extractor): CombinedExtractor(
#     (extractors): ModuleDict(
#       (coin_dists): Flatten(start_dim=1, end_dim=-1)
#       (coins): Flatten(start_dim=1, end_dim=-1)
#       (collected_coins): Flatten(start_dim=1, end_dim=-1)
#       (lane_coins): Flatten(start_dim=1, end_dim=-1)
#       (lane_obstacles): Flatten(start_dim=1, end_dim=-1)
#       (obstacle_dists): Flatten(start_dim=1, end_dim=-1)
#       (obstacles): Flatten(start_dim=1, end_dim=-1)
#       (player_pos): Flatten(start_dim=1, end_dim=-1)
#       (score): Flatten(start_dim=1, end_dim=-1)
#       (speed): Flatten(start_dim=1, end_dim=-1)
#     )
#   )
#   (mlp_extractor): MlpExtractor(
#     (policy_net): Sequential(
#       (0): Linear(in_features=140255, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#     (value_net): Sequential(
#       (0): Linear(in_features=140255, out_features=64, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=64, out_features=64, bias=True)
#       (3): Tanh()
#     )
#   )
#   (action_net): Linear(in_features=64, out_features=3, bias=True)
#   (value_net): Linear(in_features=64, out_features=1, bias=True)
# )

# %% [markdown]
# ### Training

# %%
model.learn(total_timesteps=TOTAL_TIMESTEPS,
            tb_log_name=MODEL_NAME,
            )
# Out:
# Logging to logs\baseline_ppo_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 397      |
# |    ep_rew_mean     | -59.8    |
# | time/              |          |
# |    fps             | 594      |
# |    iterations      | 1        |
# |    time_elapsed    | 34       |
# |    total_timesteps | 20480    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 406         |
# |    ep_rew_mean          | -43.3       |
# | time/                   |             |
# |    fps                  | 380         |
# |    iterations           | 2           |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007939317 |
# |    clip_fraction        | 0.00727     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.000171    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 17.6        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.000753   |
# |    value_loss           | 73.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 435         |
# |    ep_rew_mean          | -26.4       |
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 3           |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010753458 |
# |    clip_fraction        | 0.023       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.485       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.5        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00167    |
# |    value_loss           | 50.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 447         |
# |    ep_rew_mean          | -28         |
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 4           |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011673111 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.679       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 16.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00202    |
# |    value_loss           | 40.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 416         |
# |    ep_rew_mean          | -40.2       |
# | time/                   |             |
# |    fps                  | 314         |
# |    iterations           | 5           |
# |    time_elapsed         | 325         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.007398218 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 11.5        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00189    |
# |    value_loss           | 63.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 432         |
# |    ep_rew_mean          | -30.8       |
# | time/                   |             |
# |    fps                  | 309         |
# |    iterations           | 6           |
# |    time_elapsed         | 397         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.010655316 |
# |    clip_fraction        | 0.0453      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.604       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 36.3        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00289    |
# |    value_loss           | 57.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 462          |
# |    ep_rew_mean          | -23.3        |
# | time/                   |              |
# |    fps                  | 305          |
# |    iterations           | 7            |
# |    time_elapsed         | 469          |
# |    total_timesteps      | 143360       |
# | train/                  |              |
# |    approx_kl            | 0.0057726395 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.757        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 45.8         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000742    |
# |    value_loss           | 40.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 426          |
# |    ep_rew_mean          | -41.4        |
# | time/                   |              |
# |    fps                  | 302          |
# |    iterations           | 8            |
# |    time_elapsed         | 542          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0026405589 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.831        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.43         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 27.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 496         |
# |    ep_rew_mean          | -11.7       |
# | time/                   |             |
# |    fps                  | 299         |
# |    iterations           | 9           |
# |    time_elapsed         | 615         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.006099678 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.43        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00332    |
# |    value_loss           | 23.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 558         |
# |    ep_rew_mean          | 36.4        |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 10          |
# |    time_elapsed         | 688         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.006868078 |
# |    clip_fraction        | 0.0435      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 27.7        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00216    |
# |    value_loss           | 40.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 672          |
# |    ep_rew_mean          | 81.2         |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 11           |
# |    time_elapsed         | 760          |
# |    total_timesteps      | 225280       |
# | train/                  |              |
# |    approx_kl            | 0.0066074743 |
# |    clip_fraction        | 0.0555       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.998       |
# |    explained_variance   | 0.748        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 13.7         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 38.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 642         |
# |    ep_rew_mean          | 58.9        |
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 12          |
# |    time_elapsed         | 833         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.006296071 |
# |    clip_fraction        | 0.0253      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | 0.778       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 4.83        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00144    |
# |    value_loss           | 31.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 690         |
# |    ep_rew_mean          | 77.2        |
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 13          |
# |    time_elapsed         | 905         |
# |    total_timesteps      | 266240      |
# | train/                  |             |
# |    approx_kl            | 0.003938903 |
# |    clip_fraction        | 0.0272      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | 0.823       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 6.51        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 34.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 735        |
# |    ep_rew_mean          | 64.3       |
# | time/                   |            |
# |    fps                  | 293        |
# |    iterations           | 14         |
# |    time_elapsed         | 978        |
# |    total_timesteps      | 286720     |
# | train/                  |            |
# |    approx_kl            | 0.00486466 |
# |    clip_fraction        | 0.0399     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.922     |
# |    explained_variance   | 0.843      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 32.9       |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0015    |
# |    value_loss           | 31.6       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 739          |
# |    ep_rew_mean          | 75.4         |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 15           |
# |    time_elapsed         | 1050         |
# |    total_timesteps      | 307200       |
# | train/                  |              |
# |    approx_kl            | 0.0034272373 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.941       |
# |    explained_variance   | 0.844        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 6.94         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 23.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 841          |
# |    ep_rew_mean          | 112          |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 16           |
# |    time_elapsed         | 1120         |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0034645614 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.935       |
# |    explained_variance   | 0.893        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.49         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 25.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 832         |
# |    ep_rew_mean          | 111         |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 17          |
# |    time_elapsed         | 1190        |
# |    total_timesteps      | 348160      |
# | train/                  |             |
# |    approx_kl            | 0.005072718 |
# |    clip_fraction        | 0.0379      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.58        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00231    |
# |    value_loss           | 31.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 785          |
# |    ep_rew_mean          | 102          |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 18           |
# |    time_elapsed         | 1259         |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0042088195 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.916       |
# |    explained_variance   | 0.887        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 11.1         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 27.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 729         |
# |    ep_rew_mean          | 51.9        |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 19          |
# |    time_elapsed         | 1329        |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.005113379 |
# |    clip_fraction        | 0.0421      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.91       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 10.8        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00145    |
# |    value_loss           | 15.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 754          |
# |    ep_rew_mean          | 62.8         |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 20           |
# |    time_elapsed         | 1399         |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0033342834 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.924       |
# |    explained_variance   | 0.916        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.34         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 15.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 786          |
# |    ep_rew_mean          | 65           |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 21           |
# |    time_elapsed         | 1468         |
# |    total_timesteps      | 430080       |
# | train/                  |              |
# |    approx_kl            | 0.0033207596 |
# |    clip_fraction        | 0.0277       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.901       |
# |    explained_variance   | 0.871        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.87         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 25.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 885          |
# |    ep_rew_mean          | 97.2         |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 22           |
# |    time_elapsed         | 1538         |
# |    total_timesteps      | 450560       |
# | train/                  |              |
# |    approx_kl            | 0.0063348277 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.886       |
# |    explained_variance   | 0.911        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.81         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000821    |
# |    value_loss           | 13.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 955         |
# |    ep_rew_mean          | 147         |
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 23          |
# |    time_elapsed         | 1608        |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.004880031 |
# |    clip_fraction        | 0.0306      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.881      |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.98        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00134    |
# |    value_loss           | 14.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 976         |
# |    ep_rew_mean          | 152         |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 24          |
# |    time_elapsed         | 1677        |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.005818139 |
# |    clip_fraction        | 0.0308      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.849      |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.38        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00151    |
# |    value_loss           | 22.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.02e+03     |
# |    ep_rew_mean          | 168          |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 25           |
# |    time_elapsed         | 1746         |
# |    total_timesteps      | 512000       |
# | train/                  |              |
# |    approx_kl            | 0.0051007476 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.831       |
# |    explained_variance   | 0.92         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.86         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00184     |
# |    value_loss           | 16.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.03e+03     |
# |    ep_rew_mean          | 189          |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 26           |
# |    time_elapsed         | 1816         |
# |    total_timesteps      | 532480       |
# | train/                  |              |
# |    approx_kl            | 0.0048207575 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.825       |
# |    explained_variance   | 0.899        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.63         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 15.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.12e+03     |
# |    ep_rew_mean          | 322          |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 27           |
# |    time_elapsed         | 1885         |
# |    total_timesteps      | 552960       |
# | train/                  |              |
# |    approx_kl            | 0.0066539333 |
# |    clip_fraction        | 0.0624       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.828       |
# |    explained_variance   | 0.88         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.6          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 10.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 988          |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 28           |
# |    time_elapsed         | 1955         |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0038045966 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.825       |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.84         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 24.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+03     |
# |    ep_rew_mean          | 276          |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 29           |
# |    time_elapsed         | 2025         |
# |    total_timesteps      | 593920       |
# | train/                  |              |
# |    approx_kl            | 0.0044179335 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.805       |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.38         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0025      |
# |    value_loss           | 18.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 995         |
# |    ep_rew_mean          | 277         |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 30          |
# |    time_elapsed         | 2094        |
# |    total_timesteps      | 614400      |
# | train/                  |             |
# |    approx_kl            | 0.005575296 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.809      |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.8         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00239    |
# |    value_loss           | 22.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 894          |
# |    ep_rew_mean          | 180          |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 31           |
# |    time_elapsed         | 2165         |
# |    total_timesteps      | 634880       |
# | train/                  |              |
# |    approx_kl            | 0.0045893365 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.826       |
# |    explained_variance   | 0.9          |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.51         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 16.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 912         |
# |    ep_rew_mean          | 154         |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 32          |
# |    time_elapsed         | 2235        |
# |    total_timesteps      | 655360      |
# | train/                  |             |
# |    approx_kl            | 0.004559181 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.764      |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.66        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00135    |
# |    value_loss           | 15.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.03e+03     |
# |    ep_rew_mean          | 209          |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 33           |
# |    time_elapsed         | 2310         |
# |    total_timesteps      | 675840       |
# | train/                  |              |
# |    approx_kl            | 0.0047462126 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.736       |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.66         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 8.77         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.09e+03     |
# |    ep_rew_mean          | 243          |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 34           |
# |    time_elapsed         | 2382         |
# |    total_timesteps      | 696320       |
# | train/                  |              |
# |    approx_kl            | 0.0037126944 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.711       |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.62         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 13.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.07e+03     |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 291          |
# |    iterations           | 35           |
# |    time_elapsed         | 2457         |
# |    total_timesteps      | 716800       |
# | train/                  |              |
# |    approx_kl            | 0.0058643287 |
# |    clip_fraction        | 0.0475       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.744       |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.17         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 18.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.19e+03    |
# |    ep_rew_mean          | 393         |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 36          |
# |    time_elapsed         | 2529        |
# |    total_timesteps      | 737280      |
# | train/                  |             |
# |    approx_kl            | 0.003354277 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.758      |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.962       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00102    |
# |    value_loss           | 19.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | 347         |
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 37          |
# |    time_elapsed         | 2601        |
# |    total_timesteps      | 757760      |
# | train/                  |             |
# |    approx_kl            | 0.004251859 |
# |    clip_fraction        | 0.0293      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.756      |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.95        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00141    |
# |    value_loss           | 26.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.09e+03    |
# |    ep_rew_mean          | 355         |
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 38          |
# |    time_elapsed         | 2675        |
# |    total_timesteps      | 778240      |
# | train/                  |             |
# |    approx_kl            | 0.004931894 |
# |    clip_fraction        | 0.0363      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.758      |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 7.05        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00161    |
# |    value_loss           | 19.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 998          |
# |    ep_rew_mean          | 318          |
# | time/                   |              |
# |    fps                  | 290          |
# |    iterations           | 39           |
# |    time_elapsed         | 2748         |
# |    total_timesteps      | 798720       |
# | train/                  |              |
# |    approx_kl            | 0.0048890524 |
# |    clip_fraction        | 0.0311       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.751       |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 39.3         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 18.3         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.07e+03   |
# |    ep_rew_mean          | 390        |
# | time/                   |            |
# |    fps                  | 290        |
# |    iterations           | 40         |
# |    time_elapsed         | 2818       |
# |    total_timesteps      | 819200     |
# | train/                  |            |
# |    approx_kl            | 0.00548507 |
# |    clip_fraction        | 0.0395     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.736     |
# |    explained_variance   | 0.968      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.15       |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.00146   |
# |    value_loss           | 13.1       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.03e+03     |
# |    ep_rew_mean          | 292          |
# | time/                   |              |
# |    fps                  | 290          |
# |    iterations           | 41           |
# |    time_elapsed         | 2889         |
# |    total_timesteps      | 839680       |
# | train/                  |              |
# |    approx_kl            | 0.0041557215 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.728       |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.45         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.000689    |
# |    value_loss           | 13.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.08e+03    |
# |    ep_rew_mean          | 426         |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 42          |
# |    time_elapsed         | 2966        |
# |    total_timesteps      | 860160      |
# | train/                  |             |
# |    approx_kl            | 0.004128316 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.747      |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 7.35        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00164    |
# |    value_loss           | 20.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | 439         |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 43          |
# |    time_elapsed         | 3043        |
# |    total_timesteps      | 880640      |
# | train/                  |             |
# |    approx_kl            | 0.004722394 |
# |    clip_fraction        | 0.0274      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.76       |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.23        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00179    |
# |    value_loss           | 28.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.15e+03     |
# |    ep_rew_mean          | 453          |
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 44           |
# |    time_elapsed         | 3120         |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0046398537 |
# |    clip_fraction        | 0.0355       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.763       |
# |    explained_variance   | 0.956        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 13.3         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00164     |
# |    value_loss           | 22           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.24e+03    |
# |    ep_rew_mean          | 537         |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 45          |
# |    time_elapsed         | 3199        |
# |    total_timesteps      | 921600      |
# | train/                  |             |
# |    approx_kl            | 0.003928975 |
# |    clip_fraction        | 0.0269      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.762      |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 3.25        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00134    |
# |    value_loss           | 21.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.26e+03    |
# |    ep_rew_mean          | 559         |
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 46          |
# |    time_elapsed         | 3272        |
# |    total_timesteps      | 942080      |
# | train/                  |             |
# |    approx_kl            | 0.004306571 |
# |    clip_fraction        | 0.0338      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.768      |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 49.7        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00141    |
# |    value_loss           | 20.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.15e+03     |
# |    ep_rew_mean          | 444          |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 47           |
# |    time_elapsed         | 3348         |
# |    total_timesteps      | 962560       |
# | train/                  |              |
# |    approx_kl            | 0.0045668334 |
# |    clip_fraction        | 0.0446       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.778       |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.03         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00215     |
# |    value_loss           | 24.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.28e+03     |
# |    ep_rew_mean          | 544          |
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 48           |
# |    time_elapsed         | 3422         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0033899173 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.78        |
# |    explained_variance   | 0.938        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.77         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 19.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.26e+03    |
# |    ep_rew_mean          | 502         |
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 49          |
# |    time_elapsed         | 3498        |
# |    total_timesteps      | 1003520     |
# | train/                  |             |
# |    approx_kl            | 0.006585884 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.79       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.16        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00118    |
# |    value_loss           | 27.8        |
# -----------------------------------------

# %% [markdown]
# ### Evaluation

# %%
# seed = TOTAL_TIMESTEPS + 42 because we want to use unseen data and inital seed is 42 by default
eval_env = make_vec_env(create_env, n_envs=1, seed=int(TOTAL_TIMESTEPS + 42))  

eval = evaluate_policy(model, eval_env, n_eval_episodes=10)

# %%
print("mean reward: ", eval[0], "std reward: ", eval[1])
# Out:
# mean reward:  94.02935740000001 std reward:  153.13391394034295

# %% [markdown]
# ### Save the Model

# %%
model.save(MODEL_NAME)
